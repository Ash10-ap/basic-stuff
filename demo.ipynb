# %%
# !pip install -q accelerate peft bitsandbytes trl transformers

# %%
import torch
print(torch.__version__)
# Out:
# 2.5.1+cu118

# %%
dev= "cuda" if torch.cuda.is_available() else "cpu"
ten = torch.tensor([[1.0, 2.0, 3.0],[0.2,0.3,0.6]],
                   dtype=torch.float32,
                   device=dev
                   )

# %%
print(ten)
print(ten.shape)
# Out:
# tensor([[1.0000, 2.0000, 3.0000],
#         [0.2000, 0.3000, 0.6000]], device='cuda:0')
# torch.Size([2, 3])

# %%
x= torch.empty(size=(2,3))
print(x)
# Out:
# tensor([[0., 0., 0.],
#         [0., 0., 0.]])

# %%
# experiment with nural netowrk, creating fully connected nural network

import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import torch.utils.data as dataLoader
import torchvision.datasets as datasets
import torchvision.transforms as transforms

# %%
# !pip install unsloth
